# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Samir ELHANICHI**
#
# DATA SCIENTIST

# %% [markdown]
# _I am iterested in DATA SCIENCE because i am passionate about the amount of data available at my fingertips, and I seek to learn every day the methods of its exploitation with which I could make an impact very soon._

# %% [markdown]
# <h3>The below should test the sum function, it shows in the ouput the sum : 3+5</h3>

# %%
def sum(a,b):
    return a + b
print(sum(3,5))
# Out:
# 8

# %% [markdown]
# ---
# 1. item
# 1. item
# 1. item
# 1. item
# 1. item
#
# | Number | Spelling |
# | ------ | -------- |
# |    1   |  `one`   |
# |    2   |  `two`   |
# |    3   | `three`  |
